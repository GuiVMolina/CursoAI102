# %%
valor1 = int(input("Digite o primeiro valor: "))
valor2 = int(input("Digite o segundo valor: "))

print(f"{valor1} + {valor2} = {valor1 + valor2}")
# Out:
# Digite o primeiro valor: 1
# Digite o segundo valor: 2
# 1 + 2 = 3

# %%
conta = float(input("Qual o valor da conta? R$")) * 1.1
amigos = int(input("Quantos amigos são? "))

print(f"Fica então R${(conta / amigos):.2f} para cada um\nO valor total é de R${conta:.2f}")
# Out:
# Qual o valor da conta? 2000
# Quantos amigos são? 4
# Fica então R$550.0 para cada um
# O valor total é de R$2200.0

# %%
#F = C * 1.8 + 32
temperatura = float(input("Temperatura atual em Celsius: ")) * 1.8 + 32

print(f"Temperatura convertida para Fahrenheit: {temperatura} F°")
# Out:
# Temperatura atual em Celsius: 25
# Temperatura convertida para Fahrenheit: 77.0 F°

# %%
base = float(input("Defina a base: "))
altura = float(input("Defina a altura: "))

print(f"Área do retângulo é de {base * altura}m²")
# Out:
# Defina a base: 10
# Defina a altura: 20
# Área do retângulo é de 200.0m²

# %%
minutos = int(input("Defina o tempo em minutos: "))

print(f"Convertido em horas: {minutos // 60}h {minutos % 60}min")
# Out:
# Defina o tempo em minutos: 135
# Convertido em horas: 2h 15min

# %%
nota1 = float(input("Qual a primeira nota? "))
nota2 = float(input("Qual a segunda nota? "))
nota3 = float(input("Qual a terceira nota? "))

print(f"Média total: {(nota1 + nota2 + nota3) / 3.0}")
# Out:
# Qual a primeira nota? 10
# Qual a segunda nota? 9
# Qual a terceira nota? 8
# Média total: 9.0

# %%
anoNascimento = int(input("Digite o ano em que nasceu: "))
anoAtual = int(input("Digite o ano atual: "))

print(f"Você tem ou vai completar {anoAtual - anoNascimento} anos")
# Out:
# Digite o ano em que nasceu: 2005
# Digite o ano atual: 2026
# Você tem ou vai completar 21 anos

# %%
salario = float(input("Quanto esse trabalhador ganha por hora? R$"))
horas = int(input("Por quantas horas ele trabalha? "))

print(f"Salário Bruto: R${(salario * horas):.2f}\nValor do desconto: 8%\nSalário Líquido: R${((salario * horas) - (salario * horas * 0.08)):.2f}")
# Out:
# Quanto esse trabalhador ganha por hora? R$2000
# Por quantas horas ele trabalha? 4
# Salário Bruto: R$8000.0
# Valor do desconto: 8%
# Salário Líquido: R$7360.0

# %%
distancia = float(input("Distância a ser percorrida: "))
litro = float(input("Gasto por hora (em litro): "))
preco = float(input("Preço do litro da gasolina: "))

print(f"Preço total da viagem: R${((distancia / litro) * preco):.2f}")
# Out:
# Distância a ser percorrida: 100
# Gasto por hora (em litro): 4
# Preço do litro da gasolina: 10
# Preço total da viagem: R$250.0

# %%
preco = float(input("Preço do produto: R$"))

print(f"Valor descontado: R${(preco * 0.1):.2f}\nPreço final: R${(preco - (preco * 0.1)):.2f}")
# Out:
# Preço do produto: R$2000
# Valor descontado: R$200.0
# Preço final: R$1800.0

# %%
palavra = input("Digite a palavra: ")

print(f"Invertido a palavra '{palavra}' fica '{palavra[::-1]}'")
# Out:
# Digite a palavra: Abacate
# Invertido a palavra 'Abacate' fica 'etacabA'

# %%
aluno = input("Nome do aluno: ")
disciplia = input("Nome da disciplina: ")
n1 = float(input("1ª Nota: "))
n2 = float(input("2ª Nota: "))
n3 = float(input("3ª Nota: "))
n4 = float(input("4ª Nota: "))

print(f"--- Boletim ---\nAluno: {aluno}\nDisciplina: {disciplia}\nMédia: {(n1 + n2 + n3 + n4) / 4}")
# Out:
# Nome do aluno: Gui
# Nome da disciplina: Matemática
# 1ª Nota: 9
# 2ª Nota: 10
# 3ª Nota: 7
# 4ª Nota: 8
# --- Boletim ---
# Aluno: Gui
# Disciplina: Matemática
# Média: 8.5

# %%
numero = int(input("Digite um número de 3 casas: "))

print(f"Centena: {numero // 100}\nDezena: {numero % 10}\nUnidade: {(numero // 10) % 10}")
# Out:
# Digite um número de 3 casas: 456
# Centena: 4
# Dezena: 6
# Unidade: 5

# %%
idade = int(input("Idade do trabalhador: "))
tempo = int(input("Tempo de contribuição: "))

print(f"O trabalhador pode se aposentar? {idade >= 65 or tempo >= 35 }")
# Out:
# Idade do trabalhador: 35
# Tempo de contribuição: 35
# O trabalhador pode se aposentar? True

# %%
capital = float(input("Valor da Capital: R$"))
taxa = float(input("Valor dos juros (em %): "))
tempo = int(input("Por quantos meses está rendendo? "))

print(f"Valor total do rendimento: R${(capital * (1 + taxa/100) ** tempo):.2f}")
# Out:
# Valor da Capital: R$10000
# Valor dos juros (em %): R$20
# Por quantos meses está rendendo? 5
# Valor total do rendimento: 24883.20

# %%
total = int(input("Escolhe um total de # (hash) para serem exibidas: "))

print(f"{total * "#"}")
# Out:
# Escolhe um total de # (hash) para serem exibidas: 10
# ##########

# %%
ovos = int(input("Quantos ovos o fazendeiro colheu? "))

print(f"Ele deve então conseguir organizar em {ovos // 12} caixas\nFicará de sobra {ovos % 12} ovos")
# Out:
# Quantos ovos o fazendeiro colheu? 64
# Ele deve então conseguir organizar em 5 caixas
# Ficará de sobra 4 ovos

# %%
a = int(input("Valor A: "))
b = int(input("Valor B: "))
a, b = b, a

print(f"Novo Valor A: {a}\nNovo Valor B: {b}")
# Out:
# Valor A: 5
# Valor B: 10
# Novo Valor A: 10
# Novo Valor B: 5

# %%
arquivo = input("Digite o nome do arquivo (junto com seu tipo): ").lower()

print(f"É um PDF? {".pdf" in arquivo}")
# Out:
# Digite o nome do arquivo (junto com seu tipo): teste.pdf
# É um PDF? True

# %%
peso = float(input("Digite seu peso (em Kg): "))
altura = float(input("Digite sua altura (em m): "))

print(f"Está dentro do 'peso ideal'? {18.5 <= peso / (altura ** 2) < 25}")
# Out:
# Digite seu peso (em Kg): 70
# Digite sua altura (em m): 1.75
# Está dentro do 'peso ideal'? True

# %%
valor = float(input("Digite o valor a ser sacado: R$"))

print(f"Notas de R$50,00: {(valor // 50):.0f} \nNotas de R$10,00: {((valor % 50) // 10):.0f}")
# Out:
# Digite o valor a ser sacado: R$220
# Notas de R$50,00: 4
# Notas de R$10,00: 2

# %%
cateto1 = float(input("Digite o valor do primeiro cateto: "))
cateto2 = float(input("Digite o valor do segundo cateto: "))

print(f"Valor da hipotenusa: {(cateto1 ** 2 + cateto2 ** 2) ** 0.5}")
# Out:
# Digite o valor do primeiro cateto: 6
# Digite o valor do segundo cateto: 8
# Valor da hipotenusa: 10.0
